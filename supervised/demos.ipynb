# %% [markdown]
# # Supervised ML Algorithms

# %% [markdown]
# ## Linear Regression

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !ls -l *.py
# Out:
# -rw-r--r--  1 shrisha  staff  7340 Feb 22 01:19 decision_tree.py
# -rw-r--r--  1 shrisha  staff    33 Feb  2 00:31 gaussian_discriminant_analysis.py
# -rw-r--r--  1 shrisha  staff  3260 Feb 23 01:34 gradient_boosting_machine.py
# -rw-r--r--  1 shrisha  staff  5560 Feb 23 01:29 linear_regression.py
# -rw-r--r--  1 shrisha  staff  3245 Feb  3 11:03 naive_bayes.py
# -rw-r--r--  1 shrisha  staff  2678 Feb 22 00:50 random_forest.py
# -rw-r--r--  1 shrisha  staff  8485 Feb 23 01:30 support_vector_machine.py

# %%
run linear_regression.py

# %% [markdown]
# ## Support Vector Machine

# %%
run support_vector_machine.py

# %% [markdown]
# ## Naive Bayes

# %%
run naive_bayes.py
# Out:
# [0 1]

# %% [markdown]
# ## Decision Tree

# %%
run decision_tree.py

# %% [markdown]
# ## Random Forest

# %%
run random_forest.py
# Out:
# [0 1]

# %% [markdown]
# ## Gradient Boosting Machine

# %%
run gradient_boosting_machine.py

# %% [markdown]
# ## Gaussian Discriminant Analysis

# %%
run gaussian_discriminant_analysis.py
