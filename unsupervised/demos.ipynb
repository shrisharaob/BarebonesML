# %% [markdown]
# # Unsupervised ML Algorithms
#
# This Notebook runs the ML algorithms we implemeted from scratch in *python* on toy datasets

# %% [markdown]
# ## PCA

# %%
run pca.py

# %% [markdown]
# ## K - Means

# %%
run k_means.py

# %% [markdown]
# ## ICA

# %%
run ica.py
